# %% [markdown]
# # Import the Data

# %%
import pandas as pd 
almost_final_data = pd.read_csv('almost_final_data.csv')

# %% [markdown]
# # scrapping daily bts prices

# %%
import requests
import pandas as pd

# %%
api_key='3c63db1acd4399020c7f6eee92ec77cf'
symbol='BTCUSD'
query=f'https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}?apikey={api_key}'

# %%
response=requests.get(query)

# %%
btsdaily=pd.DataFrame(response.json()['historical'])

# %%
btsdaily
# Out:
#             date          open          high           low         close  \
# 0     2021-09-06  51760.296875  51918.902344  51545.089844  51635.515625
# 1     2021-09-05  49937.859375  51868.679688  49538.597656  51753.410156
# 2     2021-09-04  50009.324219  50545.582031  49548.781250  49944.625000
# 3     2021-09-03  49288.250000  50982.273438  48386.085938  50025.375000
# 4     2021-09-02  48807.847656  50343.421875  48652.320313  49327.722656
# ...          ...           ...           ...           ...           ...
# 1822  2016-09-10    622.927002    625.094971    622.395020    623.508972
# 1823  2016-09-09    626.351990    626.830017    620.263000    622.861023
# 1824  2016-09-08    614.635010    628.770020    613.843994    626.315979
# 1825  2016-09-07    610.572998    614.544983    608.513000    614.544006
# 1826  2016-09-06    606.505981    610.830017    605.091003    610.435974
#
#           adjClose        volume  unadjustedVolume      change  changePercent  \
# 0     51635.515625  3.186374e+10      3.186374e+10  -124.78125         -0.241
# 1     51753.410156  3.032268e+10      3.032268e+10  1815.55078          3.636
# 2     49944.625000  3.747133e+10      3.747133e+10   -64.69922         -0.129
# 3     50025.375000  4.320618e+10      4.320618e+10   737.12500          1.496
# 4     49327.722656  3.950807e+10      3.950807e+10   519.87500          1.065
# ...            ...           ...               ...         ...            ...
# 1822    623.508972  4.501680e+07      4.501680e+07     0.58197          0.093
# 1823    622.861023  6.455020e+07      6.455020e+07    -3.49097         -0.557
# 1824    626.315979  8.671300e+07      8.671300e+07    11.68097          1.900
# 1825    614.544006  7.503240e+07      7.503240e+07     3.97101          0.650
# 1826    610.435974  7.852910e+07      7.852910e+07     3.92999          0.648
#
#              vwap             label  changeOverTime
# 0     51699.83594  September 06, 21        -0.00241
# 1     51053.56250  September 05, 21         0.03636
# 2     50012.99609  September 04, 21        -0.00129
# 3     49797.91146  September 03, 21         0.01496
# 4     49441.15495  September 02, 21         0.01065
# ...           ...               ...             ...
# 1822    623.66632  September 10, 16         0.00093
# 1823    623.31801  September 09, 16        -0.00557
# 1824    622.97666  September 08, 16         0.01900
# 1825    612.53400  September 07, 16         0.00650
# 1826    608.78566  September 06, 16         0.00648
#
# [1827 rows x 13 columns]

# %%
btsdaily.to_csv('btsdaily', encoding='utf-8', index=False)

# %%
pd.read_csv('btsdaily')
# Out:
#             date          open          high           low         close  \
# 0     2021-09-06  51760.296875  51918.902344  51545.089844  51635.515625
# 1     2021-09-05  49937.859375  51868.679688  49538.597656  51753.410156
# 2     2021-09-04  50009.324219  50545.582031  49548.781250  49944.625000
# 3     2021-09-03  49288.250000  50982.273438  48386.085938  50025.375000
# 4     2021-09-02  48807.847656  50343.421875  48652.320313  49327.722656
# ...          ...           ...           ...           ...           ...
# 1822  2016-09-10    622.927002    625.094971    622.395020    623.508972
# 1823  2016-09-09    626.351990    626.830017    620.263000    622.861023
# 1824  2016-09-08    614.635010    628.770020    613.843994    626.315979
# 1825  2016-09-07    610.572998    614.544983    608.513000    614.544006
# 1826  2016-09-06    606.505981    610.830017    605.091003    610.435974
#
#           adjClose        volume  unadjustedVolume      change  changePercent  \
# 0     51635.515625  3.186374e+10      3.186374e+10  -124.78125         -0.241
# 1     51753.410156  3.032268e+10      3.032268e+10  1815.55078          3.636
# 2     49944.625000  3.747133e+10      3.747133e+10   -64.69922         -0.129
# 3     50025.375000  4.320618e+10      4.320618e+10   737.12500          1.496
# 4     49327.722656  3.950807e+10      3.950807e+10   519.87500          1.065
# ...            ...           ...               ...         ...            ...
# 1822    623.508972  4.501680e+07      4.501680e+07     0.58197          0.093
# 1823    622.861023  6.455020e+07      6.455020e+07    -3.49097         -0.557
# 1824    626.315979  8.671300e+07      8.671300e+07    11.68097          1.900
# 1825    614.544006  7.503240e+07      7.503240e+07     3.97101          0.650
# 1826    610.435974  7.852910e+07      7.852910e+07     3.92999          0.648
#
#              vwap             label  changeOverTime
# 0     51699.83594  September 06, 21        -0.00241
# 1     51053.56250  September 05, 21         0.03636
# 2     50012.99609  September 04, 21        -0.00129
# 3     49797.91146  September 03, 21         0.01496
# 4     49441.15495  September 02, 21         0.01065
# ...           ...               ...             ...
# 1822    623.66632  September 10, 16         0.00093
# 1823    623.31801  September 09, 16        -0.00557
# 1824    622.97666  September 08, 16         0.01900
# 1825    612.53400  September 07, 16         0.00650
# 1826    608.78566  September 06, 16         0.00648
#
# [1827 rows x 13 columns]

# %% [markdown]
# # basline model using only historical data

# %%
import math
import matplotlib.pyplot as plt
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
# Out:
# 2021-09-06 16:51:09.115462: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-09-06 16:51:09.115542: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#df=pd.read_csv('btsdaily')[::-1].reset_index()
#df=df.drop('index',axis=1)
df = almost_final_data.drop(columns='Unnamed: 0')
df
# Out:
#           start  sentimentscore          open          high           low  \
# 0    2018-01-01        4.087525  14112.200195  14112.200195  13154.700195
# 1    2018-01-02        4.721295  13625.000000  15444.599609  13163.599609
# 2    2018-01-03        6.096648  14978.200195  15572.799805  14844.500000
# 3    2018-01-04        4.738479  15270.700195  15739.700195  14522.200195
# 4    2018-01-05        5.809624  15477.200195  17705.199219  15202.799805
# ..          ...             ...           ...           ...           ...
# 840  2020-06-05        3.835772   9800.215820   9869.237305   9663.216797
# 841  2020-06-06        5.522719   9664.904297   9773.431641   9591.024414
# 842  2020-06-07        7.953006   9653.002930   9768.498047   9458.150391
# 843  2020-06-08        5.930273   9760.063477   9782.306641   9675.885742
# 844  2020-06-09        5.651405   9774.360352   9836.369141   9664.719727
#
#             close      adjClose        volume  unadjustedVolume      change  \
# 0    13657.200195  13657.200195  1.029120e+10      1.029120e+10  -455.00000
# 1    14982.099609  14982.099609  1.684660e+10      1.684660e+10  1357.09961
# 2    15201.000000  15201.000000  1.687190e+10      1.687190e+10   222.79981
# 3    15599.200195  15599.200195  2.178320e+10      2.178320e+10   328.50000
# 4    17429.500000  17429.500000  2.384090e+10      2.384090e+10  1952.29981
# ..            ...           ...           ...               ...         ...
# 840   9665.533203   9665.533203  2.350963e+10      2.350963e+10  -134.68262
# 841   9653.679688   9653.679688  2.043842e+10      2.043842e+10   -11.22461
# 842   9758.852539   9758.852539  2.501525e+10      2.501525e+10   105.84961
# 843   9771.489258   9771.489258  2.148635e+10      2.148635e+10    11.42578
# 844   9795.700195   9795.700195  2.371784e+10      2.371784e+10    21.33984
#
#      changePercent         vwap  changeOverTime       UpperBB      LowerBB  \
# 0           -3.224  13641.36686        -0.03224  20532.876074  5012.581523
# 1            9.960  14530.09961         0.09960  20514.236225  5368.125747
# 2            1.487  15206.09994         0.01487  20488.303236  5736.668737
# 3            2.151  15287.03353         0.02151  20492.881190  6063.437189
# 4           12.614  16779.16634         0.12614  20605.405339  6333.225442
# ..             ...          ...             ...           ...          ...
# 840         -1.374   9732.66244        -0.01374  10684.840323  6982.883993
# 841         -0.116   9672.71191        -0.00116  10680.510600  7089.513522
# 842          1.097   9661.83366         0.01097  10684.250302  7185.821319
# 843          0.117   9743.22721         0.00117  10677.012396  7296.341803
# 844          0.218   9765.59635         0.00218  10637.177676  7452.726191
#
#       volatility        rsi        macd  real_score  post_per_day
# 0    1290.493390  46.256417   95.011453    0.191187         464.0
# 1    1018.066882  51.765003  112.782434    0.476037         594.0
# 2     883.368621  52.628926  142.882437    0.689065         620.0
# 3     864.964200  54.234716  196.602028   -0.144155         629.0
# 4    1103.623175  60.810539  382.456370    0.197948         686.0
# ..           ...        ...         ...         ...           ...
# 840   380.495887  55.283176  234.334651    0.507125         190.0
# 841   380.195465  55.089118  224.215150    0.355522         154.0
# 842   339.654263  56.546600  222.121465    0.655545         166.0
# 843   298.674502  56.728307  218.957873    0.495176         155.0
# 844   218.914568  57.098460  215.915385    0.403074         180.0
#
# [845 rows x 20 columns]

# %%
training_split=0.7
training_index=int(0.7*len(df))

# %%
training_set = df.iloc[:training_index, 1:2].values
test_set = df.iloc[training_index:, 1:2].values

training_set.shape
# Out:
# (591, 1)

# %% [markdown]
# ## scaling

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

#TimeSteps
timesteps=20




# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(timesteps, training_index):
    X_train.append(training_set_scaled[i-timesteps:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 20))
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9267/297845858.py in <module>
#      16     y_train.append(training_set_scaled[i, 0])
#      17 X_train, y_train = np.array(X_train), np.array(y_train)
# ---> 18 X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 20))
#      19 X_train.shape
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~/.pyenv/versions/3.8.6/envs/cryptocurrency_trading/lib/python3.8/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     296            [3, 4],
#     297            [5, 6]])
# --> 298     """
#     299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#
# ~/.pyenv/versions/3.8.6/envs/cryptocurrency_trading/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55         return _wrapit(obj, method, *args, **kwds)
#      56
# ---> 57     try:
#      58         return bound(*args, **kwds)
#      59     except TypeError:
#
# ValueError: cannot reshape array of size 11420 into shape (571,20,20)

# %% [markdown]
# ## model sequential

# %%
model = Sequential()
# #Adding the first LSTM layer and some Dropout regularisation
# model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
# model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
# model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
# model.add(LSTM(units = 50, return_sequences = True))
# model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 20))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mae')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 15s 110ms/step - loss: 0.2212
# Epoch 2/100
# 18/18 [==============================] - 2s 104ms/step - loss: 0.1643
# Epoch 3/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.1623
# Epoch 4/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.1607
# Epoch 5/100
# 18/18 [==============================] - 2s 125ms/step - loss: 0.1596
# Epoch 6/100
# 18/18 [==============================] - 2s 117ms/step - loss: 0.1608
# Epoch 7/100
# 18/18 [==============================] - 3s 148ms/step - loss: 0.1609
# Epoch 8/100
# 18/18 [==============================] - 3s 140ms/step - loss: 0.1593
# Epoch 9/100
# 18/18 [==============================] - 2s 117ms/step - loss: 0.1572
# Epoch 10/100
# 18/18 [==============================] - 2s 123ms/step - loss: 0.1607
# Epoch 11/100
# 18/18 [==============================] - 2s 120ms/step - loss: 0.1617
# Epoch 12/100
# 18/18 [==============================] - 3s 177ms/step - loss: 0.1584
# Epoch 13/100
# 18/18 [==============================] - 2s 101ms/step - loss: 0.1577
# Epoch 14/100
# 18/18 [==============================] - 2s 120ms/step - loss: 0.1563
# Epoch 15/100
# 18/18 [==============================] - 3s 188ms/step - loss: 0.1580
# Epoch 16/100
# 18/18 [==============================] - 3s 166ms/step - loss: 0.1571
# Epoch 17/100
# 18/18 [==============================] - 2s 123ms/step - loss: 0.1578
# Epoch 18/100
# 18/18 [==============================] - 2s 92ms/step - loss: 0.1565: 0s - loss: 0.1
# Epoch 19/100
# 18/18 [==============================] - 2s 100ms/step - loss: 0.1571
# Epoch 20/100
# 18/18 [==============================] - 3s 152ms/step - loss: 0.1600
# Epoch 21/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.1603
# Epoch 22/100
# 18/18 [==============================] - 1s 79ms/step - loss: 0.1582
# Epoch 23/100
# 18/18 [==============================] - 3s 145ms/step - loss: 0.1581
# Epoch 24/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.1570
# Epoch 25/100
# 18/18 [==============================] - 3s 138ms/step - loss: 0.1567
# Epoch 26/100
# 18/18 [==============================] - 3s 162ms/step - loss: 0.1614
# Epoch 27/100
# 18/18 [==============================] - 2s 81ms/step - loss: 0.1557
# Epoch 28/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.1577
# Epoch 29/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.1564
# Epoch 30/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.1586
# Epoch 31/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1573
# Epoch 32/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.1569
# Epoch 33/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1565
# Epoch 34/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1582
# Epoch 35/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.1546
# Epoch 36/100
# 18/18 [==============================] - 1s 59ms/step - loss: 0.1551
# Epoch 37/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1558
# Epoch 38/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1573
# Epoch 39/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1577
# Epoch 40/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1607
# Epoch 41/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1564
# Epoch 42/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1562
# Epoch 43/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1555
# Epoch 44/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1537
# Epoch 45/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.1539
# Epoch 46/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.1565
# Epoch 47/100
# 18/18 [==============================] - 1s 82ms/step - loss: 0.1542
# Epoch 48/100
# 18/18 [==============================] - 1s 71ms/step - loss: 0.1577
# Epoch 49/100
# 18/18 [==============================] - 1s 67ms/step - loss: 0.1588
# Epoch 50/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1540
# Epoch 51/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1559
# Epoch 52/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1585
# Epoch 53/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1561
# Epoch 54/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1580
# Epoch 55/100
# 18/18 [==============================] - 1s 59ms/step - loss: 0.1547
# Epoch 56/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.1530
# Epoch 57/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1590
# Epoch 58/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1558
# Epoch 59/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1544
# Epoch 60/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1566
# Epoch 61/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1546
# Epoch 62/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1543
# Epoch 63/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1567: 0s - loss: 0
# Epoch 64/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1535
# Epoch 65/100
# 18/18 [==============================] - 1s 80ms/step - loss: 0.1567: 0
# Epoch 66/100
# 18/18 [==============================] - 1s 75ms/step - loss: 0.1562
# Epoch 67/100
# 18/18 [==============================] - 1s 73ms/step - loss: 0.1516
# Epoch 68/100
# 18/18 [==============================] - 2s 99ms/step - loss: 0.1548
# Epoch 69/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.1558
# Epoch 70/100
# 18/18 [==============================] - 2s 85ms/step - loss: 0.1560
# Epoch 71/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1541
# Epoch 72/100
# 18/18 [==============================] - 1s 58ms/step - loss: 0.1539
# Epoch 73/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1542
# Epoch 74/100
# 18/18 [==============================] - 1s 66ms/step - loss: 0.1542
# Epoch 75/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1534
# Epoch 76/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1536
# Epoch 77/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.1548
# Epoch 78/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.1557
# Epoch 79/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.1526
# Epoch 80/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1547
# Epoch 81/100
# 18/18 [==============================] - 1s 59ms/step - loss: 0.1541
# Epoch 82/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.1545
# Epoch 83/100
# 18/18 [==============================] - 1s 78ms/step - loss: 0.1550
# Epoch 84/100
# 18/18 [==============================] - 2s 114ms/step - loss: 0.1559
# Epoch 85/100
# 18/18 [==============================] - 2s 140ms/step - loss: 0.1543
# Epoch 86/100
# 18/18 [==============================] - 2s 116ms/step - loss: 0.1530
# Epoch 87/100
# 18/18 [==============================] - 3s 149ms/step - loss: 0.1529
# Epoch 88/100
# 18/18 [==============================] - 2s 121ms/step - loss: 0.1540
# Epoch 89/100
# 18/18 [==============================] - 1s 71ms/step - loss: 0.1545
# Epoch 90/100
# 18/18 [==============================] - 1s 71ms/step - loss: 0.1566
# Epoch 91/100
# 18/18 [==============================] - 1s 68ms/step - loss: 0.1564
# Epoch 92/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.1563
# Epoch 93/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.1541
# Epoch 94/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.1547
# Epoch 95/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.1525
# Epoch 96/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1554
# Epoch 97/100
# 18/18 [==============================] - 1s 61ms/step - loss: 0.1520
# Epoch 98/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.1532
# Epoch 99/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1519
# Epoch 100/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.1527

# %% [markdown]
# ## Prepare test Data

# %%
dataset_train = df.iloc[:training_index, 1:2]
dataset_test = df.iloc[training_index:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 1:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(timesteps,len(df)-training_index):
    X_test.append(inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (234, 20, 1)

# %%
predicted_bts_price = model.predict(X_test)
predicted_bts_price = sc.inverse_transform(predicted_bts_price)
predicted_bts_price.shape
# Out:
# (234, 1)

# %% [markdown]
# ## Plot

# %%
# Visualising the results
plt.plot(df.loc[training_index:, 'date'], dataset_test.values, color = 'red', label = 'Real BTS Price')
plt.plot(df.loc[training_index+timesteps:, 'date'], predicted_bts_price, color = 'blue', label = 'Predicted BTS Price')
plt.xticks(np.arange(0,len(df)-training_index,50))


plt.title('BTS Prediction')
plt.xlabel('Time')
plt.ylabel('BTS Price')
plt.legend()
plt.rcParams["figure.figsize"] = (50,10)
plt.show()

# %% [markdown]
# ## MSE

# %%
MSE= sum((dataset_test.values[timesteps:]-predicted_bts_price)**2)/len(predicted_bts_price)
MSE
# Out:
# array([2.48281408])

# %%
# pip install -U scikit-learn

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(dataset_test.values[timesteps:], predicted_bts_price)
# Out:
# 0.2979213945200612
