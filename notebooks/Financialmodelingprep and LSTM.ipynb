# %% [markdown]
# # scrapping daily bts prices

# %%
import requests
import pandas as pd

# %%
api_key='3c63db1acd4399020c7f6eee92ec77cf'
symbol='BTCUSD'
query=f'https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}?apikey={api_key}'

# %%
response=requests.get(query)

# %%
btsdaily=pd.DataFrame(response.json()['historical'])

# %%
btsdaily
# Out:
#             date          open          high           low         close  \
# 0     2021-09-01  46909.667969  47217.042969  46573.097656  47041.230469
# 1     2021-08-31  46940.296875  47195.351563  46787.875000  47179.195313
# 2     2021-08-30  48834.851563  48925.605469  46950.273438  47054.984375
# 3     2021-08-29  48911.250000  49644.113281  47925.855469  48829.832031
# 4     2021-08-28  49072.585938  49283.503906  48499.238281  48902.402344
# ...          ...           ...           ...           ...           ...
# 1822  2016-09-05    608.989990    609.054993    602.242004    606.590027
# 1823  2016-09-04    598.590027    611.836975    596.848022    608.633972
# 1824  2016-09-03    575.554993    599.500000    574.056030    598.211975
# 1825  2016-09-02    572.409973    575.643005    570.810974    575.536987
# 1826  2016-09-01    575.546021    576.310974    571.814026    572.302979
#
#           adjClose        volume  unadjustedVolume      change  changePercent  \
# 0     47041.230469  3.593810e+10      3.593810e+10   131.56250          0.280
# 1     47179.195313  3.043963e+10      3.043963e+10   238.89844          0.509
# 2     47054.984375  3.184701e+10      3.184701e+10 -1779.86719         -3.645
# 3     48829.832031  2.588965e+10      2.588965e+10   -81.41797         -0.166
# 4     48902.402344  2.856810e+10      2.856810e+10  -170.18359         -0.347
# ...            ...           ...               ...         ...            ...
# 1822    606.590027  8.244680e+07      8.244680e+07    -2.39996         -0.394
# 1823    608.633972  9.794290e+07      9.794290e+07    10.04395          1.678
# 1824    598.211975  1.590140e+08      1.590140e+08    22.65698          3.937
# 1825    575.536987  7.991080e+07      7.991080e+07     3.12701          0.546
# 1826    572.302979  7.692340e+07      7.692340e+07    -3.24304         -0.563
#
#              vwap             label  changeOverTime
# 0     46943.79036  September 01, 21         0.00280
# 1     47054.14063     August 31, 21         0.00509
# 2     47643.62109     August 30, 21        -0.03645
# 3     48799.93359     August 29, 21        -0.00166
# 4     48895.04818     August 28, 21        -0.00347
# ...           ...               ...             ...
# 1822    605.96234  September 05, 16        -0.00394
# 1823    605.77299  September 04, 16         0.01678
# 1824    590.58934  September 03, 16         0.03937
# 1825    573.99699  September 02, 16         0.00546
# 1826    573.47599  September 01, 16        -0.00563
#
# [1827 rows x 13 columns]

# %%
btsdaily.to_csv('btsdaily', encoding='utf-8', index=False)

# %%
pd.read_csv('btsdaily')
# Out:
#             date          open          high           low         close  \
# 0     2021-09-01  46909.667969  47217.042969  46573.097656  47041.230469
# 1     2021-08-31  46940.296875  47195.351563  46787.875000  47179.195313
# 2     2021-08-30  48834.851563  48925.605469  46950.273438  47054.984375
# 3     2021-08-29  48911.250000  49644.113281  47925.855469  48829.832031
# 4     2021-08-28  49072.585938  49283.503906  48499.238281  48902.402344
# ...          ...           ...           ...           ...           ...
# 1822  2016-09-05    608.989990    609.054993    602.242004    606.590027
# 1823  2016-09-04    598.590027    611.836975    596.848022    608.633972
# 1824  2016-09-03    575.554993    599.500000    574.056030    598.211975
# 1825  2016-09-02    572.409973    575.643005    570.810974    575.536987
# 1826  2016-09-01    575.546021    576.310974    571.814026    572.302979
#
#           adjClose        volume  unadjustedVolume      change  changePercent  \
# 0     47041.230469  3.593810e+10      3.593810e+10   131.56250          0.280
# 1     47179.195313  3.043963e+10      3.043963e+10   238.89844          0.509
# 2     47054.984375  3.184701e+10      3.184701e+10 -1779.86719         -3.645
# 3     48829.832031  2.588965e+10      2.588965e+10   -81.41797         -0.166
# 4     48902.402344  2.856810e+10      2.856810e+10  -170.18359         -0.347
# ...            ...           ...               ...         ...            ...
# 1822    606.590027  8.244680e+07      8.244680e+07    -2.39996         -0.394
# 1823    608.633972  9.794290e+07      9.794290e+07    10.04395          1.678
# 1824    598.211975  1.590140e+08      1.590140e+08    22.65698          3.937
# 1825    575.536987  7.991080e+07      7.991080e+07     3.12701          0.546
# 1826    572.302979  7.692340e+07      7.692340e+07    -3.24304         -0.563
#
#              vwap             label  changeOverTime
# 0     46943.79036  September 01, 21         0.00280
# 1     47054.14063     August 31, 21         0.00509
# 2     47643.62109     August 30, 21        -0.03645
# 3     48799.93359     August 29, 21        -0.00166
# 4     48895.04818     August 28, 21        -0.00347
# ...           ...               ...             ...
# 1822    605.96234  September 05, 16        -0.00394
# 1823    605.77299  September 04, 16         0.01678
# 1824    590.58934  September 03, 16         0.03937
# 1825    573.99699  September 02, 16         0.00546
# 1826    573.47599  September 01, 16        -0.00563
#
# [1827 rows x 13 columns]

# %% [markdown]
# # basline model using only historical data

# %%
import math
import matplotlib.pyplot as plt
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
df=pd.read_csv('btsdaily')[::-1].reset_index()
df=df.drop('index',axis=1)
df
# Out:
#             date          open          high           low         close  \
# 0     2016-09-01    575.546021    576.310974    571.814026    572.302979
# 1     2016-09-02    572.409973    575.643005    570.810974    575.536987
# 2     2016-09-03    575.554993    599.500000    574.056030    598.211975
# 3     2016-09-04    598.590027    611.836975    596.848022    608.633972
# 4     2016-09-05    608.989990    609.054993    602.242004    606.590027
# ...          ...           ...           ...           ...           ...
# 1822  2021-08-28  49072.585938  49283.503906  48499.238281  48902.402344
# 1823  2021-08-29  48911.250000  49644.113281  47925.855469  48829.832031
# 1824  2021-08-30  48834.851563  48925.605469  46950.273438  47054.984375
# 1825  2021-08-31  46940.296875  47195.351563  46787.875000  47179.195313
# 1826  2021-09-01  46909.667969  47217.042969  46573.097656  47041.230469
#
#           adjClose        volume  unadjustedVolume      change  changePercent  \
# 0       572.302979  7.692340e+07      7.692340e+07    -3.24304         -0.563
# 1       575.536987  7.991080e+07      7.991080e+07     3.12701          0.546
# 2       598.211975  1.590140e+08      1.590140e+08    22.65698          3.937
# 3       608.633972  9.794290e+07      9.794290e+07    10.04395          1.678
# 4       606.590027  8.244680e+07      8.244680e+07    -2.39996         -0.394
# ...            ...           ...               ...         ...            ...
# 1822  48902.402344  2.856810e+10      2.856810e+10  -170.18359         -0.347
# 1823  48829.832031  2.588965e+10      2.588965e+10   -81.41797         -0.166
# 1824  47054.984375  3.184701e+10      3.184701e+10 -1779.86719         -3.645
# 1825  47179.195313  3.043963e+10      3.043963e+10   238.89844          0.509
# 1826  47041.230469  3.593810e+10      3.593810e+10   131.56250          0.280
#
#              vwap             label  changeOverTime
# 0       573.47599  September 01, 16        -0.00563
# 1       573.99699  September 02, 16         0.00546
# 2       590.58934  September 03, 16         0.03937
# 3       605.77299  September 04, 16         0.01678
# 4       605.96234  September 05, 16        -0.00394
# ...           ...               ...             ...
# 1822  48895.04818     August 28, 21        -0.00347
# 1823  48799.93359     August 29, 21        -0.00166
# 1824  47643.62109     August 30, 21        -0.03645
# 1825  47054.14063     August 31, 21         0.00509
# 1826  46943.79036  September 01, 21         0.00280
#
# [1827 rows x 13 columns]

# %%
training_split=0.7
training_index=int(0.7*len(df))

# %%
training_set = df.iloc[:training_index, 1:2].values
test_set = df.iloc[training_index:, 1:2].values

training_set.shape
# Out:
# (1278, 1)

# %% [markdown]
# ## scaling

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

#TimeSteps
timesteps=20




# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(timesteps, training_index):
    X_train.append(training_set_scaled[i-timesteps:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (1258, 20, 1)

# %% [markdown]
# ## model sequential

# %%
model = Sequential()
# #Adding the first LSTM layer and some Dropout regularisation
# model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
# model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
# model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
# model.add(LSTM(units = 50, return_sequences = True))
# model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 20))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mae')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 5s 12ms/step - loss: 0.0999
# Epoch 2/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0418
# Epoch 3/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0371
# Epoch 4/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0355
# Epoch 5/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0328
# Epoch 6/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0334
# Epoch 7/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0330
# Epoch 8/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0357
# Epoch 9/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0319
# Epoch 10/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0315
# Epoch 11/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0314
# Epoch 12/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0301
# Epoch 13/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0313
# Epoch 14/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0287
# Epoch 15/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0300
# Epoch 16/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0275
# Epoch 17/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0247
# Epoch 18/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0291
# Epoch 19/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0274
# Epoch 20/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0253
# Epoch 21/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0259
# Epoch 22/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0268
# Epoch 23/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0259
# Epoch 24/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0261
# Epoch 25/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0249
# Epoch 26/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0264
# Epoch 27/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0247
# Epoch 28/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0256
# Epoch 29/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0240
# Epoch 30/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0236
# Epoch 31/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0236
# Epoch 32/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0250
# Epoch 33/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0240
# Epoch 34/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0243
# Epoch 35/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0240
# Epoch 36/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0227
# Epoch 37/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0236
# Epoch 38/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0240
# Epoch 39/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0224
# Epoch 40/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0227
# Epoch 41/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0214
# Epoch 42/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0244
# Epoch 43/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0232
# Epoch 44/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0228
# Epoch 45/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0230
# Epoch 46/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0224
# Epoch 47/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0214
# Epoch 48/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0219
# Epoch 49/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0208
# Epoch 50/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0222
# Epoch 51/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0232
# Epoch 52/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0220
# Epoch 53/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0200
# Epoch 54/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0198
# Epoch 55/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0197
# Epoch 56/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0208
# Epoch 57/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0208
# Epoch 58/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0219
# Epoch 59/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0197
# Epoch 60/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0217
# Epoch 61/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0224
# Epoch 62/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0201
# Epoch 63/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0201
# Epoch 64/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0220
# Epoch 65/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0207
# Epoch 66/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0214
# Epoch 67/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0197
# Epoch 68/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0214
# Epoch 69/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0208
# Epoch 70/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0213
# Epoch 71/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0217
# Epoch 72/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0215
# Epoch 73/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0214
# Epoch 74/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0205
# Epoch 75/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0191
# Epoch 76/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0195
# Epoch 77/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0194
# Epoch 78/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0201
# Epoch 79/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0200
# Epoch 80/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0199
# Epoch 81/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0204
# Epoch 82/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0211
# Epoch 83/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0194
# Epoch 84/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0202
# Epoch 85/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0202
# Epoch 86/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0197
# Epoch 87/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0194
# Epoch 88/100
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0211
# Epoch 89/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0199
# Epoch 90/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0192
# Epoch 91/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0189
# Epoch 92/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0193
# Epoch 93/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0198
# Epoch 94/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0196
# Epoch 95/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0194
# Epoch 96/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0205
# Epoch 97/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0194
# Epoch 98/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0201
# Epoch 99/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0198
# Epoch 100/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0206

# %% [markdown]
# ## Prepare test Data

# %%
dataset_train = df.iloc[:training_index, 1:2]
dataset_test = df.iloc[training_index:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 1:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(timesteps,len(df)-training_index):
    X_test.append(inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (529, 20, 1)

# %%
predicted_bts_price = model.predict(X_test)
predicted_bts_price = sc.inverse_transform(predicted_bts_price)
predicted_bts_price.shape
# Out:
# (529, 1)

# %% [markdown]
# ## Plot

# %%
# Visualising the results
plt.plot(df.loc[training_index:, 'date'], dataset_test.values, color = 'red', label = 'Real BTS Price')
plt.plot(df.loc[training_index+timesteps:, 'date'], predicted_bts_price, color = 'blue', label = 'Predicted BTS Price')
plt.xticks(np.arange(0,len(df)-training_index,50))


plt.title('BTS Prediction')
plt.xlabel('Time')
plt.ylabel('BTS Price')
plt.legend()
plt.rcParams["figure.figsize"] = (50,10)
plt.show()

# %% [markdown]
# ## MSE

# %%
MSE= sum((dataset_test.values[timesteps:]-predicted_bts_price)**2)/len(predicted_bts_price)
MSE
# Out:
# array([13892562.80514294])

# %%
# pip install -U scikit-learn

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(dataset_test.values[timesteps:], predicted_bts_price)
# Out:
# 0.062274317288132604
