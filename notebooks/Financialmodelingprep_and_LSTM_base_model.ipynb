# %% [markdown]
# # scrapping daily bts prices

# %%
import requests
import pandas as pd

# %%
api_key='3c63db1acd4399020c7f6eee92ec77cf'
symbol='BTCUSD'
query=f'https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}?apikey={api_key}'

# %%
response=requests.get(query)

# %%
btsdaily=pd.DataFrame(response.json()['historical'])

# %%
btsdaily
# Out:
#             date          open          high           low         close  \
# 0     2021-08-31  46940.296875  47195.351563  46787.875000  47179.195313
# 1     2021-08-30  48716.660156  48870.296875  47929.773438  48045.187500
# 2     2021-08-29  48911.250000  49644.113281  47925.855469  48829.832031
# 3     2021-08-28  49072.585938  49283.503906  48499.238281  48902.402344
# 4     2021-08-27  46894.554688  49112.785156  46394.281250  49058.667969
# ...          ...           ...           ...           ...           ...
# 1822  2016-09-04    598.590027    611.836975    596.848022    608.633972
# 1823  2016-09-03    575.554993    599.500000    574.056030    598.211975
# 1824  2016-09-02    572.409973    575.643005    570.810974    575.536987
# 1825  2016-09-01    575.546021    576.310974    571.814026    572.302979
# 1826  2016-08-31    577.591003    577.861023    573.642029    575.471985
#
#           adjClose        volume  unadjustedVolume      change  changePercent  \
# 0     47179.195313  3.043963e+10      3.043963e+10   238.89844          0.509
# 1     48045.187500  2.693493e+10      2.693493e+10  -671.47266         -1.378
# 2     48829.832031  2.588965e+10      2.588965e+10   -81.41797         -0.166
# 3     48902.402344  2.856810e+10      2.856810e+10  -170.18359         -0.347
# 4     49058.667969  3.451108e+10      3.451108e+10  2164.11328          4.615
# ...            ...           ...               ...         ...            ...
# 1822    608.633972  9.794290e+07      9.794290e+07    10.04395          1.678
# 1823    598.211975  1.590140e+08      1.590140e+08    22.65698          3.937
# 1824    575.536987  7.991080e+07      7.991080e+07     3.12701          0.546
# 1825    572.302979  7.692340e+07      7.692340e+07    -3.24304         -0.563
# 1826    575.471985  7.584090e+07      7.584090e+07    -2.11902         -0.367
#
#              vwap             label  changeOverTime
# 0     47054.14063     August 31, 21         0.00509
# 1     48281.75260     August 30, 21        -0.01378
# 2     48799.93359     August 29, 21        -0.00166
# 3     48895.04818     August 28, 21        -0.00347
# 4     48188.57813     August 27, 21         0.04615
# ...           ...               ...             ...
# 1822    605.77299  September 04, 16         0.01678
# 1823    590.58934  September 03, 16         0.03937
# 1824    573.99699  September 02, 16         0.00546
# 1825    573.47599  September 01, 16        -0.00563
# 1826    575.65835     August 31, 16        -0.00367
#
# [1827 rows x 13 columns]

# %%
btsdaily.to_csv('btsdaily', encoding='utf-8', index=False)

# %%
pd.read_csv('btsdaily')
# Out:
#             date          open          high           low         close  \
# 0     2021-08-31  46940.296875  47195.351563  46787.875000  47179.195313
# 1     2021-08-30  48716.660156  48870.296875  47929.773438  48045.187500
# 2     2021-08-29  48911.250000  49644.113281  47925.855469  48829.832031
# 3     2021-08-28  49072.585938  49283.503906  48499.238281  48902.402344
# 4     2021-08-27  46894.554688  49112.785156  46394.281250  49058.667969
# ...          ...           ...           ...           ...           ...
# 1822  2016-09-04    598.590027    611.836975    596.848022    608.633972
# 1823  2016-09-03    575.554993    599.500000    574.056030    598.211975
# 1824  2016-09-02    572.409973    575.643005    570.810974    575.536987
# 1825  2016-09-01    575.546021    576.310974    571.814026    572.302979
# 1826  2016-08-31    577.591003    577.861023    573.642029    575.471985
#
#           adjClose        volume  unadjustedVolume      change  changePercent  \
# 0     47179.195313  3.043963e+10      3.043963e+10   238.89844          0.509
# 1     48045.187500  2.693493e+10      2.693493e+10  -671.47266         -1.378
# 2     48829.832031  2.588965e+10      2.588965e+10   -81.41797         -0.166
# 3     48902.402344  2.856810e+10      2.856810e+10  -170.18359         -0.347
# 4     49058.667969  3.451108e+10      3.451108e+10  2164.11328          4.615
# ...            ...           ...               ...         ...            ...
# 1822    608.633972  9.794290e+07      9.794290e+07    10.04395          1.678
# 1823    598.211975  1.590140e+08      1.590140e+08    22.65698          3.937
# 1824    575.536987  7.991080e+07      7.991080e+07     3.12701          0.546
# 1825    572.302979  7.692340e+07      7.692340e+07    -3.24304         -0.563
# 1826    575.471985  7.584090e+07      7.584090e+07    -2.11902         -0.367
#
#              vwap             label  changeOverTime
# 0     47054.14063     August 31, 21         0.00509
# 1     48281.75260     August 30, 21        -0.01378
# 2     48799.93359     August 29, 21        -0.00166
# 3     48895.04818     August 28, 21        -0.00347
# 4     48188.57813     August 27, 21         0.04615
# ...           ...               ...             ...
# 1822    605.77299  September 04, 16         0.01678
# 1823    590.58934  September 03, 16         0.03937
# 1824    573.99699  September 02, 16         0.00546
# 1825    573.47599  September 01, 16        -0.00563
# 1826    575.65835     August 31, 16        -0.00367
#
# [1827 rows x 13 columns]

# %% [markdown]
# # basline model using only historical data

# %%
import math
import matplotlib.pyplot as plt
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
df=pd.read_csv('btsdaily')[::-1].reset_index()
df=df.drop('index',axis=1)
df
# Out:
#             date          open          high           low         close  \
# 0     2016-08-31    577.591003    577.861023    573.642029    575.471985
# 1     2016-09-01    575.546021    576.310974    571.814026    572.302979
# 2     2016-09-02    572.409973    575.643005    570.810974    575.536987
# 3     2016-09-03    575.554993    599.500000    574.056030    598.211975
# 4     2016-09-04    598.590027    611.836975    596.848022    608.633972
# ...          ...           ...           ...           ...           ...
# 1822  2021-08-27  46894.554688  49112.785156  46394.281250  49058.667969
# 1823  2021-08-28  49072.585938  49283.503906  48499.238281  48902.402344
# 1824  2021-08-29  48911.250000  49644.113281  47925.855469  48829.832031
# 1825  2021-08-30  48716.660156  48870.296875  47929.773438  48045.187500
# 1826  2021-08-31  46940.296875  47195.351563  46787.875000  47179.195313
#
#           adjClose        volume  unadjustedVolume      change  changePercent  \
# 0       575.471985  7.584090e+07      7.584090e+07    -2.11902         -0.367
# 1       572.302979  7.692340e+07      7.692340e+07    -3.24304         -0.563
# 2       575.536987  7.991080e+07      7.991080e+07     3.12701          0.546
# 3       598.211975  1.590140e+08      1.590140e+08    22.65698          3.937
# 4       608.633972  9.794290e+07      9.794290e+07    10.04395          1.678
# ...            ...           ...               ...         ...            ...
# 1822  49058.667969  3.451108e+10      3.451108e+10  2164.11328          4.615
# 1823  48902.402344  2.856810e+10      2.856810e+10  -170.18359         -0.347
# 1824  48829.832031  2.588965e+10      2.588965e+10   -81.41797         -0.166
# 1825  48045.187500  2.693493e+10      2.693493e+10  -671.47266         -1.378
# 1826  47179.195313  3.043963e+10      3.043963e+10   238.89844          0.509
#
#              vwap             label  changeOverTime
# 0       575.65835     August 31, 16        -0.00367
# 1       573.47599  September 01, 16        -0.00563
# 2       573.99699  September 02, 16         0.00546
# 3       590.58934  September 03, 16         0.03937
# 4       605.77299  September 04, 16         0.01678
# ...           ...               ...             ...
# 1822  48188.57813     August 27, 21         0.04615
# 1823  48895.04818     August 28, 21        -0.00347
# 1824  48799.93359     August 29, 21        -0.00166
# 1825  48281.75260     August 30, 21        -0.01378
# 1826  47054.14063     August 31, 21         0.00509
#
# [1827 rows x 13 columns]

# %%
training_set = df.iloc[:1276, 1:2].values
test_set = df.iloc[1276:, 1:2].values

# %% [markdown]
# ## scaling

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 1276):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (1216, 60, 1)

# %% [markdown]
# ## model sequential

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 7s 41ms/step - loss: 0.0369
# Epoch 2/100
# 38/38 [==============================] - 2s 40ms/step - loss: 0.0064
# Epoch 3/100
# 38/38 [==============================] - 2s 40ms/step - loss: 0.0049
# Epoch 4/100
# 38/38 [==============================] - 1s 39ms/step - loss: 0.0049
# Epoch 5/100
# 38/38 [==============================] - 1s 39ms/step - loss: 0.0045
# Epoch 6/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0042
# Epoch 7/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0037
# Epoch 8/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0041
# Epoch 9/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0027
# Epoch 10/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0029
# Epoch 11/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0028
# Epoch 12/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0031
# Epoch 13/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0026
# Epoch 14/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0025
# Epoch 15/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0028
# Epoch 16/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0023
# Epoch 17/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0022
# Epoch 18/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0025
# Epoch 19/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0021
# Epoch 20/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0019
# Epoch 21/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0020
# Epoch 22/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0020
# Epoch 23/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0019
# Epoch 24/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0020
# Epoch 25/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0021
# Epoch 26/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0021
# Epoch 27/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0018
# Epoch 28/100
# 38/38 [==============================] - 2s 42ms/step - loss: 0.0023
# Epoch 29/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0019
# Epoch 30/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0020
# Epoch 31/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0017
# Epoch 32/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0016
# Epoch 33/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0021
# Epoch 34/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0018
# Epoch 35/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0022
# Epoch 36/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0015
# Epoch 37/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0016
# Epoch 38/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0016
# Epoch 39/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0018
# Epoch 40/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0015
# Epoch 41/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0017
# Epoch 42/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0015
# Epoch 43/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0016
# Epoch 44/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0012
# Epoch 45/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0014
# Epoch 46/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0015
# Epoch 47/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0011
# Epoch 48/100
# 38/38 [==============================] - 2s 43ms/step - loss: 0.0011
# Epoch 49/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0015
# Epoch 50/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0016
# Epoch 51/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0013
# Epoch 52/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0013
# Epoch 53/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0012
# Epoch 54/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0012
# Epoch 55/100
# 38/38 [==============================] - 2s 46ms/step - loss: 0.0012
# Epoch 56/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0013
# Epoch 57/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0012
# Epoch 58/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0010
# Epoch 59/100
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0011
# Epoch 60/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0010
# Epoch 61/100
# 38/38 [==============================] - 2s 46ms/step - loss: 0.0013
# Epoch 62/100
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0016
# Epoch 63/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0011
# Epoch 64/100
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0012
# Epoch 65/100
# 38/38 [==============================] - 2s 54ms/step - loss: 0.0016
# Epoch 66/100
# 38/38 [==============================] - 2s 53ms/step - loss: 0.0012
# Epoch 67/100
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0011
# Epoch 68/100
# 38/38 [==============================] - 2s 53ms/step - loss: 0.0012
# Epoch 69/100
# 38/38 [==============================] - 2s 53ms/step - loss: 0.0011
# Epoch 70/100
# 38/38 [==============================] - 2s 53ms/step - loss: 0.0012
# Epoch 71/100
# 38/38 [==============================] - 2s 53ms/step - loss: 9.7804e-04
# Epoch 72/100
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0014
# Epoch 73/100
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0010
# Epoch 74/100
# 38/38 [==============================] - 2s 51ms/step - loss: 9.5974e-04
# Epoch 75/100
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0011
# Epoch 76/100
# 38/38 [==============================] - 2s 47ms/step - loss: 8.9440e-04
# Epoch 77/100
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0011
# Epoch 78/100
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0010
# Epoch 79/100
# 38/38 [==============================] - 2s 52ms/step - loss: 9.5949e-04
# Epoch 80/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0011
# Epoch 81/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0010
# Epoch 82/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0013
# Epoch 83/100
# 38/38 [==============================] - 3s 67ms/step - loss: 8.5586e-04
# Epoch 84/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0011
# Epoch 85/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0010
# Epoch 86/100
# 38/38 [==============================] - 2s 57ms/step - loss: 9.4092e-04
# Epoch 87/100
# 38/38 [==============================] - 2s 55ms/step - loss: 0.0012
# Epoch 88/100
# 38/38 [==============================] - 2s 55ms/step - loss: 0.0010
# Epoch 89/100
# 38/38 [==============================] - 2s 54ms/step - loss: 9.5349e-04
# Epoch 90/100
# 38/38 [==============================] - 2s 55ms/step - loss: 8.9810e-04
# Epoch 91/100
# 38/38 [==============================] - 2s 55ms/step - loss: 8.7293e-04
# Epoch 92/100
# 38/38 [==============================] - 2s 54ms/step - loss: 9.5084e-04
# Epoch 93/100
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0012
# Epoch 94/100
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0010
# Epoch 95/100
# 38/38 [==============================] - 2s 48ms/step - loss: 0.0011
# Epoch 96/100
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0010
# Epoch 97/100
# 38/38 [==============================] - 2s 49ms/step - loss: 8.3773e-04
# Epoch 98/100
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0011
# Epoch 99/100
# 38/38 [==============================] - 2s 52ms/step - loss: 7.7075e-04
# Epoch 100/100
# 38/38 [==============================] - 2s 51ms/step - loss: 9.5506e-04

# %% [markdown]
# ## Prepare test Data

# %%
dataset_train = df.iloc[:1276, 1:2]
dataset_test = df.iloc[1276:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60,551):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (491, 60, 1)

# %%
predicted_bts_price = model.predict(X_test)
predicted_bts_price = sc.inverse_transform(predicted_bts_price)
predicted_bts_price.shape
# Out:
# (491, 1)

# %%
predicted_bts_price.shape
# Out:
# (491, 1)

# %% [markdown]
# ## Plot

# %%
# Visualising the results
plt.plot(df.loc[1276:, 'date'], dataset_test.values, color = 'red', label = 'Real BTS Price')
plt.plot(df.loc[1336:, 'date'], predicted_bts_price, color = 'blue', label = 'Predicted BTS Price')
plt.xticks(np.arange(0,491,50))


plt.title('BTS Prediction')
plt.xlabel('Time')
plt.ylabel('BTS Price')
plt.legend()
plt.show()

# %% [markdown]
# ## MSE

# %%
MSE= sum((dataset_test.values[60:]-predicted_bts_price)**2)/len(predicted_bts_price)
MSE
# Out:
# array([1.90050753e+08])
