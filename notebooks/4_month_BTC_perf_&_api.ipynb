# %%
import requests
import pandas as pd

# %%
api_key='a58413697e8263de9c95cab92049ea3f'
symbol='BTCUSD'
query=f'https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}?apikey={api_key}'

# %%
response=requests.get(query)

# %%
df = pd.DataFrame(response.json()['historical'])

# %%
df
# Out:
#             date          open          high           low         close  \
# 0     2021-09-07  52561.757813  52850.425781  52420.921875  52620.878906
# 1     2021-09-06  51769.003906  52700.941406  51053.679688  52633.535156
# 2     2021-09-05  49937.859375  51868.679688  49538.597656  51753.410156
# 3     2021-09-04  50009.324219  50545.582031  49548.781250  49944.625000
# 4     2021-09-03  49288.250000  50982.273438  48386.085938  50025.375000
# ...          ...           ...           ...           ...           ...
# 1822  2016-09-11    623.424011    628.817993    600.505981    606.718994
# 1823  2016-09-10    622.927002    625.094971    622.395020    623.508972
# 1824  2016-09-09    626.351990    626.830017    620.263000    622.861023
# 1825  2016-09-08    614.635010    628.770020    613.843994    626.315979
# 1826  2016-09-07    610.572998    614.544983    608.513000    614.544006
#
#           adjClose        volume  unadjustedVolume      change  changePercent  \
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
date = pd.to_datetime('2021-05-01')

# %%
df4months = df[df['date']>date]

# %%
df4months
# Out:
#           date          open          high           low         close  \
# 0   2021-09-07  52561.757813  52850.425781  52420.921875  52620.878906
# 1   2021-09-06  51769.003906  52700.941406  51053.679688  52633.535156
# 2   2021-09-05  49937.859375  51868.679688  49538.597656  51753.410156
# 3   2021-09-04  50009.324219  50545.582031  49548.781250  49944.625000
# 4   2021-09-03  49288.250000  50982.273438  48386.085938  50025.375000
# ..         ...           ...           ...           ...           ...
# 124 2021-05-06  57441.308594  58363.316406  55382.507813  56396.515625
# 125 2021-05-05  53252.164063  57911.363281  52969.054688  57424.007813
# 126 2021-05-04  57214.179688  57214.179688  53191.425781  53333.539063
# 127 2021-05-03  56620.273438  58973.308594  56590.871094  57200.292969
# 128 2021-05-02  57825.863281  57902.593750  56141.906250  56631.078125
#
#          adjClose        volume  unadjustedVolume      change  changePercent  \
# ...

# %%
df4months = df4months[['date', 'open', 'adjClose']]

# %%
df4months
# Out:
#           date          open      adjClose
# 0   2021-09-07  52561.757813  52620.878906
# 1   2021-09-06  51769.003906  52633.535156
# 2   2021-09-05  49937.859375  51753.410156
# 3   2021-09-04  50009.324219  49944.625000
# 4   2021-09-03  49288.250000  50025.375000
# ..         ...           ...           ...
# 124 2021-05-06  57441.308594  56396.515625
# 125 2021-05-05  53252.164063  57424.007813
# 126 2021-05-04  57214.179688  53333.539063
# 127 2021-05-03  56620.273438  57200.292969
# 128 2021-05-02  57825.863281  56631.078125
#
# [129 rows x 3 columns]

# %%
df4months.to_csv('../cryptocurrency_trading/data/4-month-BTC-perf.csv', encoding='utf-8', index=False)

# %%
ticker_api_url = 'https://financialmodelingprep.com/api/v3/quotes/crypto?apikey=a58413697e8263de9c95cab92049ea3f'

# %%
#!/usr/bin/env python

try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import json

# %%
def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    url = ("https://financialmodelingprep.com/api/v3/quote/BTCUSD?apikey=a58413697e8263de9c95cab92049ea3f")
    response = urlopen(url)
    data = response.read().decode("utf-8")
    return json.loads(data)

# print(get_jsonparsed_data(url)[0]['price'])

a = get_jsonparsed_data(url)
a
# Out:
# [{'symbol': 'BTCUSD',
#   'name': 'Bitcoin USD',
#   'price': 51124.895,
#   'changesPercentage': -1.5343807,
#   'change': -796.6719,
#   'dayLow': 50689.406,
#   'dayHigh': 52850.426,
#   'yearHigh': 64863.098,
#   'yearLow': 9945.11,
#   'marketCap': 900956684288.0,
#   'priceAvg50': 43586.973,
#   'priceAvg200': 46120.266,
#   'volume': 46408499200,
#   'avgVolume': 33002171708,
#   'exchange': 'CRYPTO',
#   'open': 52561.758,
#   'previousClose': 52561.758,
#   'eps': None,
#   'pe': None,
#   'earningsAnnouncement': None,
#   'sharesOutstanding': 17622661,
#   'timestamp': 1631013171}]
