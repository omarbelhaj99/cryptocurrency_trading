# %%
# Imports 
import pandas as pd
from sklearn.impute import KNNImputer
import os
import datetime
import IPython
import IPython.display
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
# Out:
# 2021-09-08 09:52:17.795171: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-09-08 09:52:17.795671: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Importing data

# %%
df = pd.read_csv('stationary_data.csv')

# %%
df.head()
# Out:
#         start  close_price  tweet_count  twitter_sentiment        volume  \
# 0  2018-01-03    -0.078084     0.068450           6.096648  2.529997e+07
# 1  2018-01-04     0.011353    -0.066855           4.738479  4.911300e+09
# 2  2018-01-05     0.085086    -0.084542           5.809624  2.057699e+09
# 3  2018-01-06    -0.105366    -0.246690           6.643630 -5.526299e+09
# 4  2018-01-07    -0.067319     0.091045           8.091246 -2.448600e+09
#
#    volatility       rsi        macd  reddit_sentiment  reddit_post_count
# 0   -0.141918  0.016552   30.100003          0.213028             -104.0
# 1   -0.021054  0.030055   53.719591         -0.833220              -17.0
# 2    0.243666  0.114442  185.854342          0.342103               48.0
# 3    0.163605  0.005255  149.031677         -0.065387             -185.0
# 4    0.006811 -0.090538   26.993014          0.184959               53.0

# %% [markdown]
# # Imputer

# %%
imputer = KNNImputer(n_neighbors=2)
df['reddit_sentiment'],df['reddit_post_count'],df['twitter_sentiment'] = imputer.fit_transform(df[['reddit_sentiment','reddit_post_count','twitter_sentiment']]).T

# %% [markdown]
# # Train Test Val Split

# %%
column_indices = {name: i for i, name in enumerate(df.columns)}

n = len(df)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

num_features = df.shape[1]

# %% [markdown]
# # Standardize

# %%
train_mean = train_df.mean()
train_std = train_df.std()

train_df = (train_df - train_mean) / train_std
val_df = (val_df - train_mean) / train_std
test_df = (test_df - train_mean) / train_std
# Out:
# /tmp/ipykernel_13235/1429736173.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train_mean = train_df.mean()
# /tmp/ipykernel_13235/1429736173.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train_std = train_df.std()

# %% [markdown]
# # Modelling

# %%
sequence_length = 7
train_df['target'] = train_df['close_price'].shift(-sequence_length)
train_df.drop('start', axis = 1, inplace = True)

# %%
train_df.dropna()
# Out:
#      close_price      macd  reddit_post_count  reddit_sentiment       rsi  \
# 0      -1.282915  0.659219          -1.244836          0.563656  0.145075
# 1       0.187977  1.176309          -0.190403         -2.187755  0.266023
# 2       1.400588  4.069058           0.597392          0.903096  1.021837
# 3      -1.731595  3.262921          -2.226549         -0.168516  0.043896
# 4      -1.105872  0.591200           0.657991          0.489839 -0.814077
# ..           ...       ...                ...               ...       ...
# 893     0.058953  0.013762          -0.578240         -0.571180 -0.005860
# 894    -0.087907 -0.071556           0.645871         -1.534328 -0.360344
# 895    -0.017652 -0.155452          -1.305435          0.530168 -0.445726
# 896     0.144526 -0.080090           0.209554          1.456391  0.175874
# 897     0.028531 -0.015658           0.221674         -0.284731  0.336402
#
#      tweet_count  twitter_sentiment  volatility    volume    target
# 0       0.409370           0.708600   -0.820883  0.005212  1.056800
# 1      -0.388832          -0.074973   -0.113681  1.203402 -2.237758
# 2      -0.493172           0.543006    1.435256  0.503616  2.510337
# 3      -1.449731           1.024172    0.966801 -1.356202 -0.248610
# 4       0.542666           1.859351    0.049367 -0.601460 -1.127149
# ..           ...                ...         ...       ...       ...
# 893     0.982887          -1.434736   -0.163125  0.137616 -0.110625
# 894     7.794126          -2.789252    0.042164 -0.550381 -0.164714
# 895    -0.612211          -2.407624   -0.030022 -0.033059 -0.170655
# 896    -6.587683          -1.985591   -0.329861 -0.434900  0.317315
# 897    -2.643976          -2.137199   -0.835570 -0.247587  0.144290
#
# [898 rows x 10 columns]

# %%
X_train = train_df.drop('target', axis = 1)
y_train = train_df['target']
dataset = tf.keras.preprocessing.timeseries_dataset_from_array(
    X_train, y_train, sequence_length=10, batch_size = 16)
# Out:
# 2021-09-08 09:52:24.193509: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-09-08 09:52:24.193774: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-09-08 09:52:24.193891: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Omar-Laptop): /proc/driver/nvidia/version does not exist
# 2021-09-08 09:52:24.198860: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
exx, exxy = next(iter(dataset))
train_df.iloc[:10]
test_df['target'] = test_df['close_price'].shift(-sequence_length)
# Out:
# 2021-09-08 09:52:24.883406: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
sample_1 = pd.DataFrame(exx[0].numpy())

# %%
sample_1.columns = train_df.drop(columns = 'target').columns

# %%
sample_1
# Out:
#    close_price      macd  reddit_post_count  reddit_sentiment       rsi  \
# 0    -1.282915  0.659219          -1.244836          0.563656  0.145075
# 1     0.187977  1.176309          -0.190403         -2.187755  0.266023
# 2     1.400588  4.069058           0.597392          0.903096  1.021837
# 3    -1.731595  3.262921          -2.226549         -0.168516  0.043896
# 4    -1.105872  0.591200           0.657991          0.489839 -0.814077
# 5    -0.343035 -1.959509           2.572938          0.280390 -0.987329
# 6     0.725799 -2.655829          -1.281196         -0.540476 -0.433820
# 7     1.056800 -1.507488          -0.505521          1.080213  0.307582
# 8    -2.237758 -3.988060           1.118548         -1.073881 -1.205913
# 9     2.510337 -2.144758          -2.299269         -0.547355  0.537809
#
#    tweet_count  twitter_sentiment  volatility    volume
# 0     0.409370           0.708600   -0.820883  0.005212
# 1    -0.388832          -0.074973   -0.113681  1.203402
# 2    -0.493172           0.543006    1.435256  0.503616
# 3    -1.449731           1.024172    0.966801 -1.356202
# 4     0.542666           1.859351    0.049367 -0.601460
# 5     1.151345          -0.668360   -0.184221  0.623827
# 6     0.538181           0.855073   -0.026156 -0.431100
# 7     0.209730          -0.650843   -0.044257  0.450426
# 8     0.811707           0.019531    0.342525 -0.483284
# 9    -1.164093           1.101803    0.122919 -1.096774

# %%
train_df.head(10)
# Out:
#    close_price      macd  reddit_post_count  reddit_sentiment       rsi  \
# 0    -1.282915  0.659219          -1.244836          0.563656  0.145075
# 1     0.187977  1.176309          -0.190403         -2.187755  0.266023
# 2     1.400588  4.069058           0.597392          0.903096  1.021837
# 3    -1.731595  3.262921          -2.226549         -0.168516  0.043896
# 4    -1.105872  0.591200           0.657991          0.489839 -0.814077
# 5    -0.343035 -1.959509           2.572938          0.280390 -0.987329
# 6     0.725799 -2.655829          -1.281196         -0.540476 -0.433820
# 7     1.056800 -1.507488          -0.505521          1.080213  0.307582
# 8    -2.237758 -3.988060           1.118548         -1.073881 -1.205913
# 9     2.510337 -2.144758          -2.299269         -0.547355  0.537809
#
#    tweet_count  twitter_sentiment  volatility    volume    target
# 0     0.409370           0.708600   -0.820883  0.005212  1.056800
# 1    -0.388832          -0.074973   -0.113681  1.203402 -2.237758
# 2    -0.493172           0.543006    1.435256  0.503616  2.510337
# 3    -1.449731           1.024172    0.966801 -1.356202 -0.248610
# 4     0.542666           1.859351    0.049367 -0.601460 -1.127149
# 5     1.151345          -0.668360   -0.184221  0.623827  0.746063
# 6     0.538181           0.855073   -0.026156 -0.431100 -3.091359
# 7     0.209730          -0.650843   -0.044257  0.450426  2.599016
# 8     0.811707           0.019531    0.342525 -0.483284  0.854676
# 9    -1.164093           1.101803    0.122919 -1.096774 -0.225464

# %%
exxy[0].numpy()
# Out:
# 1.056799714593014

# %%
test_df.drop('start', axis = 1, inplace = True)

# %%
X_test = test_df.drop('target', axis = 1)
y_test = test_df['target']

# %%
dataset_test = tf.keras.preprocessing.timeseries_dataset_from_array(
    X_test, y_test, sequence_length=10)

# %%
etx, ety = next(iter(dataset_test))
val_df['target'] = val_df['close_price'].shift(-sequence_length)
val_df.drop('start', axis = 1, inplace = True)
X_val = val_df.drop('target', axis = 1)
y_val =val_df['target']
dataset_val = tf.keras.preprocessing.timeseries_dataset_from_array(
    X_val, y_val, sequence_length=10)
evx, evy = next(iter(dataset_val))

# %% [markdown]
# # Train model

# %%
lstm_model = tf.keras.models.Sequential([
    # Shape [batch, time, features] => [batch, time, lstm_units]
    tf.keras.layers.GRU(128, return_sequences=True),
    tf.keras.layers.GRU(64),
    #tf.keras.layers.Dropout(0.2),
    # Shape => [batch, time, features]
    tf.keras.layers.Dense(units=32),
    tf.keras.layers.Dense(units=16),
    tf.keras.layers.Dense(units=1)
    # Adding a second LSTM layer and some Dropout regularisation
])

# regularization?
# GRU layer

# %%
lstm_model.compile(optimizer = 'Adam', loss = 'mae')

# %%
es = EarlyStopping(patience = 20, restore_best_weights=True)

# %%
reduce_lr = ReduceLROnPlateau(patience = 15)

# %%
lstm_model.fit(dataset, validation_data = dataset_val, epochs = 2_000, callbacks = [es, reduce_lr])
# Out:
# Epoch 1/2000
# 56/56 [==============================] - 23s 137ms/step - loss: 0.6683 - val_loss: 0.6363
# Epoch 2/2000
# 56/56 [==============================] - 5s 88ms/step - loss: 0.6514 - val_loss: 0.6318
# Epoch 3/2000
# 56/56 [==============================] - 5s 82ms/step - loss: 0.6407 - val_loss: 0.6320
# Epoch 4/2000
# 56/56 [==============================] - 4s 74ms/step - loss: 0.5558 - val_loss: 0.4714
# Epoch 5/2000
# 56/56 [==============================] - 4s 77ms/step - loss: 0.2096 - val_loss: 0.2993
# Epoch 6/2000
# 56/56 [==============================] - 4s 66ms/step - loss: 0.1438 - val_loss: 0.3069
# Epoch 7/2000
# 56/56 [==============================] - 3s 53ms/step - loss: 0.1364 - val_loss: 0.2847
# Epoch 8/2000
# 56/56 [==============================] - 3s 54ms/step - loss: 0.1276 - val_loss: 0.2755
# Epoch 9/2000
# 56/56 [==============================] - 3s 54ms/step - loss: 0.1027 - val_loss: 0.2536
# Epoch 10/2000
# 56/56 [==============================] - 3s 54ms/step - loss: 0.0932 - val_loss: 0.2391
# Epoch 11/2000
# 56/56 [==============================] - 4s 67ms/step - loss: 0.0932 - val_loss: 0.2188
# Epoch 12/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0935 - val_loss: 0.2429
# Epoch 13/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.1070 - val_loss: 0.2118
# Epoch 14/2000
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0980 - val_loss: 0.2046
# Epoch 15/2000
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0927 - val_loss: 0.1956
# Epoch 16/2000
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0819 - val_loss: 0.1867
# Epoch 17/2000
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0678 - val_loss: 0.2013
# Epoch 18/2000
# 56/56 [==============================] - 3s 59ms/step - loss: 0.0725 - val_loss: 0.1854
# Epoch 19/2000
# 56/56 [==============================] - 4s 69ms/step - loss: 0.0705 - val_loss: 0.1892
# Epoch 20/2000
# 56/56 [==============================] - 4s 64ms/step - loss: 0.0657 - val_loss: 0.1844
# Epoch 21/2000
# 56/56 [==============================] - 3s 61ms/step - loss: 0.0649 - val_loss: 0.1634
# Epoch 22/2000
# 56/56 [==============================] - 3s 63ms/step - loss: 0.0668 - val_loss: 0.1856
# Epoch 23/2000
# 56/56 [==============================] - 3s 59ms/step - loss: 0.0645 - val_loss: 0.1539
# Epoch 24/2000
# 56/56 [==============================] - 4s 65ms/step - loss: 0.0597 - val_loss: 0.1663
# Epoch 25/2000
# 56/56 [==============================] - 3s 52ms/step - loss: 0.0707 - val_loss: 0.1569
# Epoch 26/2000
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0619 - val_loss: 0.1436
# Epoch 27/2000
# 56/56 [==============================] - 4s 73ms/step - loss: 0.0627 - val_loss: 0.1538
# Epoch 28/2000
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0647 - val_loss: 0.1518
# Epoch 29/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0605 - val_loss: 0.1551
# Epoch 30/2000
# 56/56 [==============================] - 5s 86ms/step - loss: 0.0579 - val_loss: 0.1564
# Epoch 31/2000
# 56/56 [==============================] - 6s 105ms/step - loss: 0.0613 - val_loss: 0.1506
# Epoch 32/2000
# 56/56 [==============================] - 7s 118ms/step - loss: 0.0559 - val_loss: 0.1566
# Epoch 33/2000
# 56/56 [==============================] - 5s 94ms/step - loss: 0.0535 - val_loss: 0.1554
# Epoch 34/2000
# 56/56 [==============================] - 5s 83ms/step - loss: 0.0610 - val_loss: 0.1658
# Epoch 35/2000
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0463 - val_loss: 0.1486
# Epoch 36/2000
# 56/56 [==============================] - 5s 95ms/step - loss: 0.0593 - val_loss: 0.1573
# Epoch 37/2000
# 56/56 [==============================] - 4s 78ms/step - loss: 0.0562 - val_loss: 0.1590
# Epoch 38/2000
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0585 - val_loss: 0.1447
# Epoch 39/2000
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0549 - val_loss: 0.1375
# Epoch 40/2000
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0721 - val_loss: 0.1562
# Epoch 41/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0530 - val_loss: 0.1299
# Epoch 42/2000
# 56/56 [==============================] - 5s 86ms/step - loss: 0.0520 - val_loss: 0.1314
# Epoch 43/2000
# 56/56 [==============================] - 5s 85ms/step - loss: 0.0479 - val_loss: 0.1386
# Epoch 44/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0580 - val_loss: 0.1262
# Epoch 45/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0568 - val_loss: 0.1090
# Epoch 46/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0641 - val_loss: 0.1146
# Epoch 47/2000
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0591 - val_loss: 0.1490
# Epoch 48/2000
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0567 - val_loss: 0.1120
# Epoch 49/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0462 - val_loss: 0.1258
# Epoch 50/2000
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0554 - val_loss: 0.1305
# Epoch 51/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0531 - val_loss: 0.1179
# Epoch 52/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0485 - val_loss: 0.1178
# Epoch 53/2000
# 56/56 [==============================] - 5s 92ms/step - loss: 0.0430 - val_loss: 0.1298
# Epoch 54/2000
# 56/56 [==============================] - 5s 92ms/step - loss: 0.0493 - val_loss: 0.0968
# Epoch 55/2000
# 56/56 [==============================] - 5s 93ms/step - loss: 0.0433 - val_loss: 0.1107
# Epoch 56/2000
# 56/56 [==============================] - 5s 94ms/step - loss: 0.0500 - val_loss: 0.1145
# Epoch 57/2000
# 56/56 [==============================] - 5s 94ms/step - loss: 0.0437 - val_loss: 0.1158
# Epoch 58/2000
# 56/56 [==============================] - 5s 94ms/step - loss: 0.0503 - val_loss: 0.1042
# Epoch 59/2000
# 56/56 [==============================] - 5s 93ms/step - loss: 0.0486 - val_loss: 0.1262
# Epoch 60/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0474 - val_loss: 0.1282
# Epoch 61/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0462 - val_loss: 0.1022
# Epoch 62/2000
# 56/56 [==============================] - 5s 94ms/step - loss: 0.0546 - val_loss: 0.1227
# Epoch 63/2000
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0487 - val_loss: 0.1070
# Epoch 64/2000
# 56/56 [==============================] - 5s 94ms/step - loss: 0.0463 - val_loss: 0.1081
# Epoch 65/2000
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0499 - val_loss: 0.1219
# Epoch 66/2000
# 56/56 [==============================] - 5s 94ms/step - loss: 0.0518 - val_loss: 0.0967
# Epoch 67/2000
# 56/56 [==============================] - 5s 94ms/step - loss: 0.0461 - val_loss: 0.1104
# Epoch 68/2000
# 56/56 [==============================] - 5s 96ms/step - loss: 0.0467 - val_loss: 0.1104
# Epoch 69/2000
# 56/56 [==============================] - 7s 118ms/step - loss: 0.0407 - val_loss: 0.0975
# Epoch 70/2000
# 56/56 [==============================] - 8s 136ms/step - loss: 0.0442 - val_loss: 0.1080
# Epoch 71/2000
# 56/56 [==============================] - 5s 92ms/step - loss: 0.0427 - val_loss: 0.0904
# Epoch 72/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0436 - val_loss: 0.1032
# Epoch 73/2000
# 56/56 [==============================] - 5s 93ms/step - loss: 0.0483 - val_loss: 0.1061
# Epoch 74/2000
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0413 - val_loss: 0.1027
# Epoch 75/2000
# 56/56 [==============================] - 5s 87ms/step - loss: 0.0363 - val_loss: 0.1042
# Epoch 76/2000
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0395 - val_loss: 0.0981
# Epoch 77/2000
# 56/56 [==============================] - 5s 86ms/step - loss: 0.0478 - val_loss: 0.1102
# Epoch 78/2000
# 56/56 [==============================] - 6s 101ms/step - loss: 0.0451 - val_loss: 0.0887
# Epoch 79/2000
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0465 - val_loss: 0.0906
# Epoch 80/2000
# 56/56 [==============================] - 5s 95ms/step - loss: 0.0434 - val_loss: 0.0953
# Epoch 81/2000
# 56/56 [==============================] - 5s 86ms/step - loss: 0.0406 - val_loss: 0.0967
# Epoch 82/2000
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0391 - val_loss: 0.1155
# Epoch 83/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0493 - val_loss: 0.0841
# Epoch 84/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0454 - val_loss: 0.1075
# Epoch 85/2000
# 56/56 [==============================] - 4s 80ms/step - loss: 0.0431 - val_loss: 0.0755
# Epoch 86/2000
# 56/56 [==============================] - 8s 138ms/step - loss: 0.0465 - val_loss: 0.1016
# Epoch 87/2000
# 56/56 [==============================] - 6s 106ms/step - loss: 0.0439 - val_loss: 0.0994
# Epoch 88/2000
# 56/56 [==============================] - 4s 74ms/step - loss: 0.0407 - val_loss: 0.0886
# Epoch 89/2000
# 56/56 [==============================] - 4s 74ms/step - loss: 0.0361 - val_loss: 0.0868
# Epoch 90/2000
# 56/56 [==============================] - 4s 74ms/step - loss: 0.0311 - val_loss: 0.0913
# Epoch 91/2000
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0350 - val_loss: 0.0930
# Epoch 92/2000
# 56/56 [==============================] - 4s 77ms/step - loss: 0.0378 - val_loss: 0.0910
# Epoch 93/2000
# 56/56 [==============================] - 4s 79ms/step - loss: 0.0390 - val_loss: 0.0921
# Epoch 94/2000
# 56/56 [==============================] - 4s 80ms/step - loss: 0.0455 - val_loss: 0.0940
# Epoch 95/2000
# 56/56 [==============================] - 4s 80ms/step - loss: 0.0608 - val_loss: 0.0883
# Epoch 96/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0354 - val_loss: 0.0829
# Epoch 97/2000
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0339 - val_loss: 0.0877
# Epoch 98/2000
# 56/56 [==============================] - 4s 81ms/step - loss: 0.0424 - val_loss: 0.0941
# Epoch 99/2000
# 56/56 [==============================] - 5s 85ms/step - loss: 0.0461 - val_loss: 0.0846
# Epoch 100/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0349 - val_loss: 0.0829
# Epoch 101/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0289 - val_loss: 0.0718
# Epoch 102/2000
# 56/56 [==============================] - 5s 86ms/step - loss: 0.0187 - val_loss: 0.0726
# Epoch 103/2000
# 56/56 [==============================] - 5s 93ms/step - loss: 0.0163 - val_loss: 0.0715
# Epoch 104/2000
# 56/56 [==============================] - 5s 88ms/step - loss: 0.0145 - val_loss: 0.0716
# Epoch 105/2000
# 56/56 [==============================] - 6s 102ms/step - loss: 0.0135 - val_loss: 0.0712
# Epoch 106/2000
# 56/56 [==============================] - 5s 97ms/step - loss: 0.0118 - val_loss: 0.0712
# Epoch 107/2000
# 56/56 [==============================] - 5s 92ms/step - loss: 0.0121 - val_loss: 0.0705
# Epoch 108/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0108 - val_loss: 0.0705
# Epoch 109/2000
# 56/56 [==============================] - 5s 87ms/step - loss: 0.0108 - val_loss: 0.0696
# Epoch 110/2000
# 56/56 [==============================] - 5s 92ms/step - loss: 0.0112 - val_loss: 0.0694
# Epoch 111/2000
# 56/56 [==============================] - 5s 92ms/step - loss: 0.0112 - val_loss: 0.0692
# Epoch 112/2000
# 56/56 [==============================] - 5s 95ms/step - loss: 0.0104 - val_loss: 0.0681
# Epoch 113/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0092 - val_loss: 0.0680
# Epoch 114/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0092 - val_loss: 0.0669
# Epoch 115/2000
# 56/56 [==============================] - 5s 93ms/step - loss: 0.0093 - val_loss: 0.0671
# Epoch 116/2000
# 56/56 [==============================] - 5s 95ms/step - loss: 0.0099 - val_loss: 0.0684
# Epoch 117/2000
# 56/56 [==============================] - 5s 96ms/step - loss: 0.0102 - val_loss: 0.0683
# Epoch 118/2000
# 56/56 [==============================] - 6s 102ms/step - loss: 0.0086 - val_loss: 0.0662
# Epoch 119/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0078 - val_loss: 0.0671
# Epoch 120/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0083 - val_loss: 0.0669
# Epoch 121/2000
# 56/56 [==============================] - 4s 79ms/step - loss: 0.0080 - val_loss: 0.0656
# Epoch 122/2000
# 56/56 [==============================] - 4s 79ms/step - loss: 0.0084 - val_loss: 0.0656
# Epoch 123/2000
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0086 - val_loss: 0.0636
# Epoch 124/2000
# 56/56 [==============================] - 4s 79ms/step - loss: 0.0084 - val_loss: 0.0657
# Epoch 125/2000
# 56/56 [==============================] - 4s 80ms/step - loss: 0.0079 - val_loss: 0.0637
# Epoch 126/2000
# 56/56 [==============================] - 4s 79ms/step - loss: 0.0080 - val_loss: 0.0643
# Epoch 127/2000
# 56/56 [==============================] - 4s 75ms/step - loss: 0.0078 - val_loss: 0.0650
# Epoch 128/2000
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0078 - val_loss: 0.0640
# Epoch 129/2000
# 56/56 [==============================] - 5s 85ms/step - loss: 0.0078 - val_loss: 0.0638
# Epoch 130/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0077 - val_loss: 0.0635
# Epoch 131/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0073 - val_loss: 0.0639
# Epoch 132/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0083 - val_loss: 0.0634
# Epoch 133/2000
# 56/56 [==============================] - 5s 85ms/step - loss: 0.0072 - val_loss: 0.0622
# Epoch 134/2000
# 56/56 [==============================] - 5s 83ms/step - loss: 0.0078 - val_loss: 0.0632
# Epoch 135/2000
# 56/56 [==============================] - 5s 87ms/step - loss: 0.0081 - val_loss: 0.0612
# Epoch 136/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0073 - val_loss: 0.0629
# Epoch 137/2000
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0068 - val_loss: 0.0625
# Epoch 138/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0078 - val_loss: 0.0640
# Epoch 139/2000
# 56/56 [==============================] - 5s 92ms/step - loss: 0.0090 - val_loss: 0.0634
# Epoch 140/2000
# 56/56 [==============================] - 5s 89ms/step - loss: 0.0087 - val_loss: 0.0626
# Epoch 141/2000
# 56/56 [==============================] - 5s 87ms/step - loss: 0.0069 - val_loss: 0.0630
# Epoch 142/2000
# 56/56 [==============================] - 4s 81ms/step - loss: 0.0070 - val_loss: 0.0630
# Epoch 143/2000
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0072 - val_loss: 0.0622
# Epoch 144/2000
# 56/56 [==============================] - 4s 80ms/step - loss: 0.0067 - val_loss: 0.0628
# Epoch 145/2000
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0071 - val_loss: 0.0617
# Epoch 146/2000
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0069 - val_loss: 0.0636
# Epoch 147/2000
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0067 - val_loss: 0.0616
# Epoch 148/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0064 - val_loss: 0.0614
# Epoch 149/2000
# 56/56 [==============================] - 5s 83ms/step - loss: 0.0063 - val_loss: 0.0624
# Epoch 150/2000
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0062 - val_loss: 0.0611
# Epoch 151/2000
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0066 - val_loss: 0.0609
# Epoch 152/2000
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0059 - val_loss: 0.0607
# Epoch 153/2000
# 56/56 [==============================] - 5s 88ms/step - loss: 0.0057 - val_loss: 0.0606
# Epoch 154/2000
# 56/56 [==============================] - 5s 97ms/step - loss: 0.0054 - val_loss: 0.0604
# Epoch 155/2000
# 56/56 [==============================] - 7s 117ms/step - loss: 0.0053 - val_loss: 0.0603
# Epoch 156/2000
# 56/56 [==============================] - 5s 88ms/step - loss: 0.0054 - val_loss: 0.0604
# Epoch 157/2000
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0051 - val_loss: 0.0601
# Epoch 158/2000
# 56/56 [==============================] - 3s 62ms/step - loss: 0.0050 - val_loss: 0.0603
# Epoch 159/2000
# 56/56 [==============================] - 3s 54ms/step - loss: 0.0049 - val_loss: 0.0602
# Epoch 160/2000
# 56/56 [==============================] - 3s 47ms/step - loss: 0.0048 - val_loss: 0.0600
# Epoch 161/2000
# 56/56 [==============================] - 2s 44ms/step - loss: 0.0047 - val_loss: 0.0600
# Epoch 162/2000
# 56/56 [==============================] - 2s 44ms/step - loss: 0.0046 - val_loss: 0.0599
# Epoch 163/2000
# 56/56 [==============================] - 3s 45ms/step - loss: 0.0046 - val_loss: 0.0600
# Epoch 164/2000
# 56/56 [==============================] - 3s 45ms/step - loss: 0.0046 - val_loss: 0.0601
# Epoch 165/2000
# 56/56 [==============================] - 3s 61ms/step - loss: 0.0046 - val_loss: 0.0599
# Epoch 166/2000
# 56/56 [==============================] - 4s 70ms/step - loss: 0.0045 - val_loss: 0.0600
# Epoch 167/2000
# 56/56 [==============================] - 4s 73ms/step - loss: 0.0045 - val_loss: 0.0598
# Epoch 168/2000
# 56/56 [==============================] - 5s 97ms/step - loss: 0.0044 - val_loss: 0.0596
# Epoch 169/2000
# 56/56 [==============================] - 4s 68ms/step - loss: 0.0044 - val_loss: 0.0598
# Epoch 170/2000
# 56/56 [==============================] - 4s 68ms/step - loss: 0.0043 - val_loss: 0.0596
# Epoch 171/2000
# 56/56 [==============================] - 4s 64ms/step - loss: 0.0044 - val_loss: 0.0598
# Epoch 172/2000
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0044 - val_loss: 0.0594
# Epoch 173/2000
# 56/56 [==============================] - 3s 60ms/step - loss: 0.0043 - val_loss: 0.0593
# Epoch 174/2000
# 56/56 [==============================] - 3s 53ms/step - loss: 0.0043 - val_loss: 0.0593
# Epoch 175/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0044 - val_loss: 0.0594
# Epoch 176/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0043 - val_loss: 0.0594
# Epoch 177/2000
# 56/56 [==============================] - 3s 52ms/step - loss: 0.0043 - val_loss: 0.0592
# Epoch 178/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0042 - val_loss: 0.0591
# Epoch 179/2000
# 56/56 [==============================] - 3s 52ms/step - loss: 0.0042 - val_loss: 0.0593
# Epoch 180/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0042 - val_loss: 0.0591
# Epoch 181/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0041 - val_loss: 0.0591
# Epoch 182/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0041 - val_loss: 0.0591
# Epoch 183/2000
# 56/56 [==============================] - 3s 53ms/step - loss: 0.0042 - val_loss: 0.0590
# Epoch 184/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0041 - val_loss: 0.0592
# Epoch 185/2000
# 56/56 [==============================] - 3s 49ms/step - loss: 0.0041 - val_loss: 0.0590
# Epoch 186/2000
# 56/56 [==============================] - 3s 52ms/step - loss: 0.0041 - val_loss: 0.0588
# Epoch 187/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0041 - val_loss: 0.0590
# Epoch 188/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0039 - val_loss: 0.0590
# Epoch 189/2000
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0039 - val_loss: 0.0591
# Epoch 190/2000
# 56/56 [==============================] - 3s 60ms/step - loss: 0.0040 - val_loss: 0.0588
# Epoch 191/2000
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0041 - val_loss: 0.0590
# Epoch 192/2000
# 56/56 [==============================] - 3s 45ms/step - loss: 0.0039 - val_loss: 0.0590
# Epoch 193/2000
# 56/56 [==============================] - 2s 44ms/step - loss: 0.0039 - val_loss: 0.0588
# Epoch 194/2000
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0039 - val_loss: 0.0589
# Epoch 195/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0038 - val_loss: 0.0588
# Epoch 196/2000
# 56/56 [==============================] - 2s 44ms/step - loss: 0.0038 - val_loss: 0.0588
# Epoch 197/2000
# 56/56 [==============================] - 3s 46ms/step - loss: 0.0039 - val_loss: 0.0587
# Epoch 198/2000
# 56/56 [==============================] - 3s 47ms/step - loss: 0.0039 - val_loss: 0.0587
# Epoch 199/2000
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0037 - val_loss: 0.0589
# Epoch 200/2000
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0038 - val_loss: 0.0588
# Epoch 201/2000
# 56/56 [==============================] - 3s 45ms/step - loss: 0.0037 - val_loss: 0.0587
# Epoch 202/2000
# 56/56 [==============================] - 3s 45ms/step - loss: 0.0037 - val_loss: 0.0586
# Epoch 203/2000
# 56/56 [==============================] - 2s 43ms/step - loss: 0.0037 - val_loss: 0.0589
# Epoch 204/2000
# 56/56 [==============================] - 2s 44ms/step - loss: 0.0036 - val_loss: 0.0586
# Epoch 205/2000
# 56/56 [==============================] - 2s 44ms/step - loss: 0.0037 - val_loss: 0.0587
# Epoch 206/2000
# 56/56 [==============================] - 2s 44ms/step - loss: 0.0036 - val_loss: 0.0590
# Epoch 207/2000
# 56/56 [==============================] - 2s 45ms/step - loss: 0.0037 - val_loss: 0.0587
# Epoch 208/2000
# 56/56 [==============================] - 2s 45ms/step - loss: 0.0036 - val_loss: 0.0587
# Epoch 209/2000
# 56/56 [==============================] - 3s 48ms/step - loss: 0.0036 - val_loss: 0.0585
# Epoch 210/2000
# 56/56 [==============================] - 3s 59ms/step - loss: 0.0037 - val_loss: 0.0585
# Epoch 211/2000
# 56/56 [==============================] - 3s 47ms/step - loss: 0.0036 - val_loss: 0.0586
# Epoch 212/2000
# 56/56 [==============================] - 3s 46ms/step - loss: 0.0035 - val_loss: 0.0589
# Epoch 213/2000
# 56/56 [==============================] - 3s 54ms/step - loss: 0.0036 - val_loss: 0.0586
# Epoch 214/2000
# 56/56 [==============================] - 3s 52ms/step - loss: 0.0035 - val_loss: 0.0586
# Epoch 215/2000
# 56/56 [==============================] - 4s 66ms/step - loss: 0.0035 - val_loss: 0.0589
# Epoch 216/2000
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0034 - val_loss: 0.0586
# Epoch 217/2000
# 56/56 [==============================] - 4s 72ms/step - loss: 0.0035 - val_loss: 0.0584
# Epoch 218/2000
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0036 - val_loss: 0.0586
# Epoch 219/2000
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0034 - val_loss: 0.0587
# Epoch 220/2000
# 56/56 [==============================] - 3s 58ms/step - loss: 0.0034 - val_loss: 0.0585
# Epoch 221/2000
# 56/56 [==============================] - 3s 52ms/step - loss: 0.0034 - val_loss: 0.0587
# Epoch 222/2000
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0034 - val_loss: 0.0586
# Epoch 223/2000
# 56/56 [==============================] - 3s 53ms/step - loss: 0.0035 - val_loss: 0.0587
# Epoch 224/2000
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0034 - val_loss: 0.0588
# Epoch 225/2000
# 56/56 [==============================] - 4s 64ms/step - loss: 0.0033 - val_loss: 0.0586
# Epoch 226/2000
# 56/56 [==============================] - 4s 68ms/step - loss: 0.0035 - val_loss: 0.0584
# Epoch 227/2000
# 56/56 [==============================] - 4s 72ms/step - loss: 0.0034 - val_loss: 0.0587
# Epoch 228/2000
# 56/56 [==============================] - 4s 69ms/step - loss: 0.0034 - val_loss: 0.0586
# Epoch 229/2000
# 56/56 [==============================] - 4s 64ms/step - loss: 0.0034 - val_loss: 0.0585
# Epoch 230/2000
# 56/56 [==============================] - 4s 63ms/step - loss: 0.0035 - val_loss: 0.0587
# Epoch 231/2000
# 56/56 [==============================] - 4s 80ms/step - loss: 0.0035 - val_loss: 0.0587
# Epoch 232/2000
# 56/56 [==============================] - 4s 80ms/step - loss: 0.0034 - val_loss: 0.0585
# Epoch 233/2000
# 56/56 [==============================] - 5s 87ms/step - loss: 0.0035 - val_loss: 0.0587
# Epoch 234/2000
# 56/56 [==============================] - 4s 74ms/step - loss: 0.0034 - val_loss: 0.0588
# Epoch 235/2000
# 56/56 [==============================] - 4s 68ms/step - loss: 0.0034 - val_loss: 0.0588
# Epoch 236/2000
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0034 - val_loss: 0.0589
# Epoch 237/2000
# 56/56 [==============================] - 4s 73ms/step - loss: 0.0033 - val_loss: 0.0589

# %%
X_train.tail()
# Out:
#      close_price      macd  reddit_post_count  reddit_sentiment       rsi  \
# 900    -0.110625  0.558168           0.064115         -1.168413  0.830402
# 901    -0.164714  0.533461          -0.178283         -0.153201  0.257786
# 902    -0.170655  0.333580           0.379233          0.887597 -0.357159
# 903     0.317315  0.495218          -0.299482          0.670237  0.646585
# 904     0.144290  0.769609           0.464073         -1.308545  0.767258
#
#      tweet_count  twitter_sentiment  volatility    volume
# 900     0.364181          -1.762147    1.154331 -0.377990
# 901     0.391031          -2.600100    1.638994  0.394843
# 902    -0.221532          -2.638534    0.721922 -0.391797
# 903    -0.703370          -2.331410    1.073531  0.013060
# 904    -0.006306          -1.020457    1.565271  0.954893

# %%
lstm_model.evaluate(dataset_test)
# Out:
# 1/1 [==============================] - 0s 230ms/step - loss: 0.1042
# 0.104178786277771

# %%
y_pred = lstm_model.predict(dataset_test)

# %%
etx, ety = next(iter(dataset_test))

# %%
y_test = ety.numpy()

# %%
y_pred = y_pred*train_std['close_price']+train_mean['close_price']

# %%
(y_pred >0).flatten().mean()
# Out:
# 0.48760330578512395

# %%
y_test = y_test*train_std['close_price']+train_mean['close_price']

# %%
len(y_test)
# Out:
# 121

# %%
plt.plot(y_test, label = 'test')
plt.plot(y_pred, label = 'actual')
plt.legend()

# %%
((y_pred.flatten() > 0) == (y_test>0)).mean()
# Out:
# 0.9752066115702479

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, None, 128)         53376
# _________________________________________________________________
# gru_1 (GRU)                  (None, 64)                37248
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 93,249
# Trainable params: 93,249
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.scatter(x = range(len(train_df)), y = train_df.target)
